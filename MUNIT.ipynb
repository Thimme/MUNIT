# %% [markdown]
# ### Clone the MUNIT repository

# %%
# !nvidia-smi
# !cat /etc/*release
# Out:
# Wed Aug 12 13:35:32 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P8    35W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/Thimme/MUNIT.git
# Out:
# Cloning into 'MUNIT'...
# remote: Enumerating objects: 418, done.
# remote: Total 418 (delta 0), reused 0 (delta 0), pack-reused 418
# Receiving objects: 100% (418/418), 6.11 MiB | 4.14 MiB/s, done.
# Resolving deltas: 100% (212/212), done.

# %%
# !pip install torch==0.4.1 torchvision==0.2.2 pillow==6.2.1
# !pip install tensorboard tensorboardX
# Out:
# ...
#      |████████████████████████████████| 519.5MB 36kB/s
# ...
#      |████████████████████████████████| 71kB 8.7MB/s
# ...
#      |████████████████████████████████| 2.1MB 39.5MB/s
# ...
#      |████████████████████████████████| 61kB 8.0MB/s
# ERROR: spacy 2.2.4 has requirement tqdm<5.0.0,>=4.38.0, but you'll have tqdm 4.19.9 which is incompatible.
# ERROR: fastai 1.0.61 has requirement torch>=1.0.0, but you'll have torch 0.4.1 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: torch 1.6.0+cu101
#     Uninstalling torch-1.6.0+cu101:
#       Successfully uninstalled torch-1.6.0+cu101
#   Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# ...

# %%
import os
os.chdir('MUNIT/')

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Test

# %%
# !python test.py --config configs/edges2shoes_folder.yaml --input inputs/edges2shoes_edge.jpg --output_folder outputs --checkpoint models/edges2shoes.pt --a2b 1

# %%
# !python test.py --config configs/edges2shoes_folder.yaml --input inputs/edges2shoes_edge.jpg --output_folder outputs --checkpoint models/edges2shoes.pt --a2b 1 --style inputs/edges2shoes_shoe.jpg

# %% [markdown]
# ### Train

# %%
# !tar -xf ./datasets/normal2fog.tar.gz

# %%
# !python train.py --config configs/edges2handbags_folder.yaml
# Out:
# Creating directory: ./outputs/edges2handbags_folder/images
# Creating directory: ./outputs/edges2handbags_folder/checkpoints
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/upsampling.py:122: UserWarning: nn.Upsampling is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.Upsampling is deprecated. Use nn.functional.interpolate instead.")
# Elapsed time in update: 7.665497
# Elapsed time in update: 1.822510
# Elapsed time in update: 1.823843
# Elapsed time in update: 1.828901
# Elapsed time in update: 1.836069
# Elapsed time in update: 1.838190
# Elapsed time in update: 1.835504
# Elapsed time in update: 1.834636
# Elapsed time in update: 1.838699
# Elapsed time in update: 1.845623
# Iteration: 00000010/01000000
# Elapsed time in update: 1.843270
# Elapsed time in update: 1.843735
# Elapsed time in update: 1.853598
# Elapsed time in update: 1.838440
# Elapsed time in update: 1.836233
# Elapsed time in update: 1.843757
# Elapsed time in update: 1.851190
# ...
